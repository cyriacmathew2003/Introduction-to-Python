# %% [markdown]
# <a href="https://colab.research.google.com/github/cyriacmathew2003/Introduction-to-Python/blob/main/pandas_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
supermarket=files.upload()
# Out:
#      <input type="file" id="files-f1a12aea-7264-4152-9413-0b20250b4755" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1a12aea-7264-4152-9413-0b20250b4755">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
team=files.upload()
# Out:
#      <input type="file" id="files-9ecd19e4-ebba-4fde-9c7f-8ca373fd22c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ecd19e4-ebba-4fde-9c7f-8ca373fd22c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
teamgoals={
    'team':['spain','england'],
    'goals':[2,4]}

teamgoaldf=pd.DataFrame(teamgoals)
print(teamgoaldf)
# Out:
#       team  goals
# 0    spain      2
# 1  england      4

# %%
marks={
    'subject':['English','Science','Social','Computer','Syriac'],
    'marks':[40,50,80,90,70]}

teamgoaldf=pd.DataFrame(marks)
print(marks)
# Out:
# {'subject': ['English', 'Science', 'Social', 'Computer', 'Syriac'], 'marks': [40, 50, 80, 90, 70]}

# %%
import pandas 
dataframe=pandas.read_csv("Supermarket_sales.csv")
print(dataframe)
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
import pandas as pd
dataframe=pd.read_csv('Supermarket_sales.csv')
print(dataframe)
print("********")
print(dataframe.head(5))
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
import pandas as pd
sub=['hindi','english','fa','cra','dmbs']
mark=[30,40,50,67,80]
mark1={'subject':sub,'marks':mark}
marks=pd.DataFrame(sub,mark)
print(marks)
# Out:
#           0
# 30    hindi
# 40  english
# 50       fa
# 67      cra
# 80     dmbs

# %%
import pandas as pd
dataframe=pd.read_csv('Supermarket_sales.csv')
print(dataframe)
print("********")
print(dataframe.head(5))
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
dataframe['City']
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
print(dataframe['City'],dataframe['Branch'])
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object 0      A
# 1      C
# 2      A
# 3      A
# 4      A
#       ..
# 995    C
# 996    B
# 997    A
# 998    A
# 999    A
# Name: Branch, Length: 1000, dtype: object

# %%
print(dataframe.index)
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
for i in dataframe.index:
  print(dataframe.City[i],dataframe.Branch[i])
# Out:
# Yangon A
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Yangon A
# Naypyitaw C
# Mandalay B
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Mandalay B
# Mandalay B
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Naypyitaw C
# Mandalay B
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Naypyitaw C
# ...

# %%
from google.colab import files
ff=files.upload()
# Out:
#      <input type="file" id="files-cc27679f-82f7-4aa7-8d4d-7a17c1da49f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc27679f-82f7-4aa7-8d4d-7a17c1da49f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
fifadataframe = pandas.read_csv("players_20.csv")
max_overall=fifadataframe.overall.max()
max_overall_loc =fifadataframe.overall.idxmax()
person=fifadataframe.loc[max_overall_loc]
print(person.long_name," has the  highest overall of",max_overall)
# Out:
# Lionel Andrés Messi Cuccittini  has the  highest overall of 94

# %%
df2=pd.read_csv('players_20.csv')
max=df2.overall.max()
max2=df2.age.max()
#max1=df2.overall.idxmax()
#per=df2.loc[max_overall_loc]
#print(person.long_name,'has the highest overall of',max_overall)
print(max2)
# Out:
# 42

# %%
fifadataframe = pandas.read_csv("players_20.csv")
max_overall=fifadataframe.age.idxmax()
print(max_overall)
# Out:
# 11832

# %%
for i in fifadataframe.index:
  if fifadataframe.club[i] == "FC Barcelona":
    print(fifadataframe.short_name[i])
# Out:
# L. Messi
# M. ter Stegen
# L. Suárez
# Sergio Busquets
# A. Griezmann
# Piqué
# Jordi Alba
# S. Umtiti
# I. Rakitić
# F. de Jong
# C. Lenglet
# Neto
# O. Dembélé
# Arthur
# A. Vidal
# Nélson Semedo
# Sergi Roberto
# Rafinha
# Junior Firpo
# Aleñá
# Riqui Puig
# J. Todibo
# M. Wagué
# H. Abe
# L. Reis
# Abel Ruiz
# Oriol Busquets
# Carles Pérez
# Miranda
# Chumi
# Álex Collado
# Jorge Cuenca
# Iñaki Peña
